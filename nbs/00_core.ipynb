# %% [markdown]
# # core
#
# > Fill in a module description here

# %%
#| default_exp core

# %%
#| hide
from nbdev.showdoc import *
import subprocess

# %%
#| export
def test_mmseq():
    # Source - https://stackoverflow.com/a
    # Posted by EmmEff, modified by community. See post 'Timeline' for change history
    # Retrieved 2025-11-14, License - CC BY-SA 4.0
    p = subprocess.Popen('mmseqs', shell=True, stdout=subprocess.PIPE, stderr=subprocess.STDOUT)
    for line in p.stdout.readlines():
        print (line)
        break
    retval = p.wait()
    print(retval)

# %%
test_mmseq()
# Out:
# b'MMseqs2 (Many against Many sequence searching) is an open-source software suite for very fast, \n'
# 0

# %%
#| hide
import nbdev; nbdev.nbdev_export()
